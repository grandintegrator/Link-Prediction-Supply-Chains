# %% [markdown]
# # Running Sweeps 🚀

# %%
import os
os.chdir('../src')

# %%
import wandb
import yaml
from managers.trainer import Trainer
from ingestion.dataloader import SCDataLoader
from utils import create_model
from typing import Dict, Any
# Out:
# Using backend: pytorch

# %% [markdown]
# Loading config files - the normal and the sweep config file.

# %%
os.chdir('..')
with open('config/sweep_config.yml', 'r') as yaml_file:
    sweep_config_file = yaml.safe_load(yaml_file)

# %% [markdown]
# Adding in metrics, parameters, and sweeping method into the `sweep_config` variable.

# %%
sweep_config = {
    'method': 'bayes',
    'parameters': sweep_config_file
}

# %%
metric = {
    'name': 'Training AUC buys_from',
    'goal': 'minimize'   
}
sweep_config['metric'] = metric

# %% [markdown]
# Generate a sweep ID for `project="KG-Completion-Sweep"`

# %%
sweep_id = wandb.sweep(sweep_config, project="KG-Completion-Sweep")
# Out:
# Create sweep with ID: 1ci43bxo
# Sweep URL: https://wandb.ai/grandintegrator/KG-Completion-Sweep/sweeps/1ci43bxo

# %%
def train(config=None):
    # Initialize a new weights and biases run
    with wandb.init(config=config):
        config = wandb.config
        data_loader = SCDataLoader(params=config)
        train_loader = data_loader.get_training_dataloader()
        graph_model = \
            create_model(params=config,
                         graph_edge_types=data_loader.edge_types)
        trainer = Trainer(params=config, model=graph_model,
                          train_data_loader=train_loader)
        trainer.train()

# %%
wandb.agent(sweep_id, train, count=20)
# Out:
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=20
# wandb: Agent Starting Run: 9x0jmxb3 with config:
# wandb: 	batch_size: 12
# wandb: 	capability_product_weight_cut: 200
# wandb: 	cg_weight_cut: 30
# wandb: 	device: cpu
# wandb: 	eval_type: validation
# wandb: 	evaluate_every: 3
# wandb: 	from_scratch: False
# wandb: 	graph_save_path: data/02_intermediate/
# wandb: 	l2_regularisation: 0.0005
# wandb: 	load_graph: True
# wandb: 	log_company_accuracy: False
# wandb: 	log_freq: 20
# wandb: 	loss: margin
# wandb: 	lr: 1e-05
# wandb: 	momentum: 0.0005
# wandb: 	num_classes: 2
# wandb: 	num_epochs: 1000
# wandb: 	num_hidden_graph_layers: 10
# wandb: 	num_negative_samples: 3
# wandb: 	num_node_features: 10
# wandb: 	num_workers: 0
# wandb: 	optimiser: SGD
# wandb: 	save_train_results: False
# wandb: 	stream_wandb: True
# wandb: 	test_p: 0.1
# wandb: 	triplets_from_scratch: False
# wandb: 	valid_p: 0.2
# wandb: Currently logged in as: grandintegrator (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">autumn-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep</a><br/>
#                 Sweep page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep/sweeps/1ci43bxo" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep/sweeps/1ci43bxo</a><br/>
# Run page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9x0jmxb3" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9x0jmxb3</a><br/>
#                 Run data is saved locally in <code>/Users/tim-bhp/PycharmProjects/link_predictions_supply_chains/Link-Prediction-Supply-Chains/wandb/run-20210610_111046-9x0jmxb3</code><br/><br/>
# INFO:ingestion.dataset:Graphs loaded locally with the following dimensions:
# INFO:ingestion.dataset:====================================================
# INFO:ingestion.dataset:cG should have 14018 edges
# INFO:ingestion.dataset:bG should have 119618 edges
# INFO:ingestion.dataset:G should have 88997 edges
# INFO:ingestion.dataset:capability_product_graph should have 21575 edges
# INFO:ingestion.dataset:company_capability_graph should have 83787 edges
# INFO:ingestion.dataset:36 Capabilities
# INFO:ingestion.dataset:119618 Processes
# INFO:ingestion.dataset:41826 Companies
# INFO:ingestion.dataset:====================================================
# INFO:ingestion.dgl_dataset:All graphs loaded to memory - moving to process...
# INFO:ingestion.dgl_dataset:Triplets loaded from memory, processing to torch...
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'l2_regularisation' was locked by 'sweep' (ignored update).
# 100%|██████████| 37801/37801 [1:17:18<00:00,  8.15it/s, loss=3.017]
# <br/>Waiting for W&B process to finish, PID 71539<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.01MB of 0.01MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/Users/tim-bhp/PycharmProjects/link_predictions_supply_chains/Link-Prediction-Supply-Chains/wandb/run-20210610_111046-9x0jmxb3/logs/debug.log</code>
# Find internal logs for this run at: <code>/Users/tim-bhp/PycharmProjects/link_predictions_supply_chains/Link-Prediction-Supply-Chains/wandb/run-20210610_111046-9x0jmxb3/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>37779</td></tr><tr><td>Training loss</td><td>3.54377</td></tr><tr><td>Training AUC buys_from</td><td>0.7</td></tr><tr><td>Training AUC has_capability</td><td>0.75</td></tr><tr><td>Training AUC has_cert</td><td>0.5</td></tr><tr><td>Training AUC located_in</td><td>0.35</td></tr><tr><td>Training AUC makes_product</td><td>0.25</td></tr><tr><td>Training AUC complimentary_product_to</td><td>0.8625</td></tr><tr><td>Training AP buys_from</td><td>0.25</td></tr><tr><td>Training AP has_capability</td><td>0.25</td></tr><tr><td>Training AP has_cert</td><td>0.14286</td></tr><tr><td>Training AP located_in</td><td>0.10049</td></tr><tr><td>Training AP makes_product</td><td>0.08929</td></tr><tr><td>Training AP complimentary_product_to</td><td>0.43056</td></tr><tr><td>_runtime</td><td>4655</td></tr><tr><td>_timestamp</td><td>1623299301</td></tr><tr><td>_step</td><td>37779</td></tr><tr><td>Training AUC capability_produces</td><td>0.9</td></tr><tr><td>Training AP capability_produces</td><td>0.5</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>
synced 6 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">autumn-sweep-1</strong>: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9x0jmxb3" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9x0jmxb3</a><br/>
# wandb: Agent Starting Run: 9okipb0p with config:
# wandb: 	batch_size: 32
# wandb: 	capability_product_weight_cut: 200
# wandb: 	cg_weight_cut: 30
# wandb: 	device: cpu
# wandb: 	eval_type: validation
# wandb: 	evaluate_every: 3
# wandb: 	from_scratch: False
# wandb: 	graph_save_path: data/02_intermediate/
# wandb: 	l2_regularisation: 0.005
# wandb: 	load_graph: True
# wandb: 	log_company_accuracy: False
# wandb: 	log_freq: 20
# wandb: 	loss: binary_cross_entropy
# wandb: 	lr: 1e-05
# wandb: 	momentum: 0.0005
# wandb: 	num_classes: 2
# wandb: 	num_epochs: 500
# wandb: 	num_hidden_graph_layers: 10
# wandb: 	num_negative_samples: 50
# wandb: 	num_node_features: 2
# wandb: 	num_workers: 0
# wandb: 	optimiser: Adam
# wandb: 	save_train_results: False
# wandb: 	stream_wandb: True
# wandb: 	test_p: 0.1
# wandb: 	triplets_from_scratch: False
# wandb: 	valid_p: 0.2
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">grateful-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep</a><br/>
#                 Sweep page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep/sweeps/1ci43bxo" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep/sweeps/1ci43bxo</a><br/>
# Run page: <a href="https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9okipb0p" target="_blank">https://wandb.ai/grandintegrator/KG-Completion-Sweep/runs/9okipb0p</a><br/>
#                 Run data is saved locally in <code>/Users/tim-bhp/PycharmProjects/link_predictions_supply_chains/Link-Prediction-Supply-Chains/wandb/run-20210610_122828-9okipb0p</code><br/><br/>
# INFO:ingestion.dataset:Graphs loaded locally with the following dimensions:
# INFO:ingestion.dataset:====================================================
# INFO:ingestion.dataset:cG should have 14018 edges
# INFO:ingestion.dataset:bG should have 119618 edges
# INFO:ingestion.dataset:G should have 88997 edges
# INFO:ingestion.dataset:capability_product_graph should have 21575 edges
# INFO:ingestion.dataset:company_capability_graph should have 83787 edges
# INFO:ingestion.dataset:36 Capabilities
# INFO:ingestion.dataset:119618 Processes
# INFO:ingestion.dataset:41826 Companies
# INFO:ingestion.dataset:====================================================
# INFO:ingestion.dgl_dataset:All graphs loaded to memory - moving to process...
# INFO:ingestion.dgl_dataset:Triplets loaded from memory, processing to torch...
# wandb: WARNING Config item 'lr' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'l2_regularisation' was locked by 'sweep' (ignored update).
#  45%|████▍     | 6316/14176 [16:32<20:20,  6.44it/s, loss=1.314]
